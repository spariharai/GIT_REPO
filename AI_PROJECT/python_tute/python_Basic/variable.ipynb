# %% [markdown]
# # Variable

# %%
age=23  
name="amit"
height=5.8
is_true=True

# %%
age
# Out:
# 23

# %%
hei
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 hei
#
# NameError: name 'hei' is not defined

# %%
height
# Out:
# 5.8

# %%
print(age)
# Out:
# 23

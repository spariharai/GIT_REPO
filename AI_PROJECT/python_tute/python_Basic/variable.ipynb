# %% [markdown]
# # Variable

# %%
age=23  
name="amit"
height=5.8
is_true=True

# %%
age
# Out:
# 23

# %%
hei
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 hei
#
# NameError: name 'hei' is not defined

# %%
height
# Out:
# 5.8

# %%
print(age)
# Out:
# 23

# %%
age=23
Name="Sandeep"
height=5.8
is_true=True
print(type(age))
print(type(Name))
print(type(height))
print(type(is_true))
print("My name is",Name,"and my age is",age,"and my height is",height,"and it is",is_true,"that I am a human being")
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
